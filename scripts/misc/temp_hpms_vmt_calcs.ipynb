# %%
import geopandas as gpd

# %%
def load_data(gdb, layer):
    '''
    Summary: Load data from the geodatabase
    Inputs:
        - gdb (str): Path to the geodatabase
        - layer (str): Name of the layer to load
    Output:
        - gpd.DataFrame: Geopandas DataFrame containing the data
    '''
    return gpd.read_file(gdb, layer=layer, engine='pyogrio', use_arrow=True)

# %%
gdf = load_data('../../data/processed_data/HPMS/HPMS.gdb', 'hpms_aadt_imputation')

# %%
gdf
# Out:
#          FID_Link_Cnty_Intxn  Shape_Length  STATEFP       STATENAME  COUNTYFP  \
# 0                          1    593.855877      NaN            None       NaN
# 1                          2     62.796861     45.0  South Carolina      63.0
# 2                          3    140.170579     45.0  South Carolina      63.0
# 3                          4    160.084386     45.0  South Carolina      63.0
# 4                          5   1460.438412     45.0  South Carolina      63.0
# ...                      ...           ...      ...             ...       ...
# 6928065              6928066    166.034651     15.0          Hawaii       1.0
# 6928066              6928067    118.009781     15.0          Hawaii       1.0
# 6928067              6928068    157.217152     15.0          Hawaii       1.0
# 6928068              6928069    164.602012     15.0          Hawaii       1.0
# 6928069              6928070      8.274417     15.0          Hawaii       1.0
#
#            GEOID  F_SYSTEM                                         URBAN_CODE  \
# 0            NaN       NaN                                               None
# 1        45063.0       3.0  0          None\n1          None\n2          N...
# 2        45063.0       3.0  0          None\n1          None\n2          N...
# 3        45063.0       3.0  0          None\n1          None\n2          N...
# 4        45063.0       1.0                                              99999
# ...          ...       ...                                                ...
# 6928065  15001.0       6.0                                              99998
# 6928066  15001.0       6.0                                              99998
# 6928067  15001.0       6.0                                              99998
# 6928068  15001.0       6.0                                              99998
# 6928069  15001.0       6.0                                              99998
#
#          URBAN  THROUGH_LANES  LANE_KMS  LANE_MILES          VKT          VMT  \
# 0          NaN            NaN       NaN         NaN          NaN          NaN
# 1          1.0            4.0  0.251187    0.156081   979.631036   608.714505
# 2          1.0            4.0  0.560682    0.348392  4541.526751  2821.973892
# 3          1.0            4.0  0.640338    0.397887  6563.459837  4078.344864
# 4          0.0            1.0  1.460438    0.907474  3651.096031  2268.685894
# ...        ...            ...       ...         ...          ...          ...
# 6928065    2.0            2.0  0.332069    0.206338   796.966324   495.211915
# 6928066    2.0            2.0  0.236020    0.146656   566.446948   351.973816
# 6928067    2.0            2.0  0.314434    0.195380   754.642329   468.913004
# 6928068    2.0            2.0  0.329204    0.204558   790.089656   490.938952
# 6928069    2.0            2.0  0.016549    0.010283    39.717204    24.679126
#
#             AADT     AADT_MDV  AADT_HDV  Shape_Length_  \
# 0            NaN          NaN       NaN            NaN
# 1        15600.0   327.000000     30.00            NaN
# 2        32400.0  3240.000000   1944.00            NaN
# 3        41000.0   766.000000    241.00            NaN
# 4         2500.0   601.461524     51.49            NaN
# ...          ...          ...       ...            ...
# 6928065   4800.0    25.000000      3.00            NaN
# 6928066   4800.0    25.000000      3.00            NaN
# 6928067   4800.0    25.000000      3.00            NaN
# 6928068   4800.0    25.000000      3.00            NaN
# 6928069   4800.0    25.000000      3.00            NaN
#
#                                                   geometry
# 0        MULTILINESTRING ((1363238.823 1321349.615, 136...
# 1        MULTILINESTRING ((1364325.223 1322043.516, 136...
# 2        MULTILINESTRING ((1365260.152 1312253.486, 136...
# 3        MULTILINESTRING ((1350827.437 1320700.616, 135...
# 4        MULTILINESTRING ((1364836.154 1313982.045, 136...
# ...                                                    ...
# 6928065  MULTILINESTRING ((-6072313.498 1619316.790, -6...
# 6928066  MULTILINESTRING ((-6072502.699 1619416.506, -6...
# 6928067  MULTILINESTRING ((-6072165.896 1619262.654, -6...
# 6928068  MULTILINESTRING ((-6072749.386 1619557.669, -6...
# 6928069  MULTILINESTRING ((-6072158.126 1619259.808, -6...
#
# [6928070 rows x 19 columns]
